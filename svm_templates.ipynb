# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
import numpy as np
from sklearn.metrics import accuracy_score, roc_auc_score
import numpy as np
from detection import SubjectData
from utils import train_subjects, test_subjects
from sklearn.metrics import roc_curve, auc, make_scorer
from sklearn.model_selection import train_test_split, GridSearchCV, LeaveOneOut,StratifiedKFold
import pandas as pd
from imblearn.over_sampling import SMOTE

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/bci-challenge-ner15/
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from google.colab import drive
#       2 drive.mount('/content/drive')
#       3 get_ipython().run_line_magic('cd', '/content/drive/MyDrive/bci-challenge-ner15/')
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
RAND_STATE = 42

# %%
labels = pd.read_csv('./data/TrainLabels.csv')
global_y = labels['Prediction'].to_numpy()
print(global_y.shape)
# Out:
# (5440,)

# %%
X = []
for subject in train_subjects:
  sd = SubjectData(subject, train=True)
  X.append(np.hstack((sd.is_short.reshape(-1, 1), sd.get_green_similarity(), sd.get_feedback_similarity())))
X = np.vstack(X)
print(X.shape)
# Out:
# (5440, 26)

# %%
test_set = []
for i in range(len(test_subjects)):
    sd = SubjectData(test_subjects[i], train=False)
    test_set.append(np.hstack((sd.is_short.reshape(-1, 1), sd.get_green_similarity(), sd.get_feedback_similarity())))

test_set = np.vstack(test_set)
print(f'test_set: {test_set.shape}')
# Out:
# test_set: (3400, 26)

# %%
def get_session_and_trial(verbose=False):
    features = []
    for i in range(1, 5):
        for j in range(1, 61):
            features.append([i, j])
    for j in range(1, 101):
        features.append([5, j])
    features = np.array(features)
    if verbose: print(f'session_and_trial: {features.shape}')
    return features

def transform_data(X, verbose=False):
  extra_features = get_session_and_trial(verbose=verbose)
  extra_cols = []
  for i in range(X.shape[0] // extra_features.shape[0]):
    extra_cols.append(extra_features)
  extra_cols = np.array(extra_cols)
  extra_cols = extra_cols.reshape(extra_cols.shape[0] * extra_cols.shape[1], extra_cols.shape[2])
  if verbose: print(f'extra_cols: {extra_cols.shape}')
  final_X = np.hstack((extra_cols, X))
  return final_X

# %%
X = transform_data(X)
test_set = transform_data(test_set)

# %%
def remove_high_correlation_columns(X, verbose=False):
  cols_to_remove = [10, 8, 18, 16, 26, 24]
  X = np.delete(X, cols_to_remove, axis=1)
  if verbose: print(f'X after removing columns: {X.shape}')
  return X

# %%
X = remove_high_correlation_columns(X)
test_set = remove_high_correlation_columns(test_set)

# %%
scaler = StandardScaler()
X = scaler.fit_transform(X)
test_set = scaler.transform(test_set)

# %%
print(X.shape)
print(test_set.shape)
# Out:
# (5440, 22)
# (3400, 22)

# %%
X_train, X_val, y_train, y_val = train_test_split(X, global_y, test_size=0.3, random_state=RAND_STATE)
print(f'X_train: {X_train.shape}\nX_val: {X_val.shape}')
# Out:
# X_train: (3808, 22)
# X_val: (1632, 22)

# %%
def loocv_with_smote_svm(X, y, best_params):
    loo = LeaveOneOut()
    y_true, y_prob = [], []

    for train_idx, test_idx in loo.split(X):
        X_train, X_test = X[train_idx], X[test_idx]
        y_train, y_test = y[train_idx], y[test_idx]

        smote = SMOTE(random_state=42)
        X_res, y_res = smote.fit_resample(X_train, y_train)

        model = SVC(**best_params, probability=True)
        model.fit(X_res, y_res)

        prob = model.predict_proba(X_test)[:, 1]
        y_true.append(y_test[0])
        y_prob.append(prob[0])

    return np.array(y_true), np.array(y_prob)

param_grid = {
    'C': [0.01, 0.1, 1, 10],  # Ευρύ φάσμα κανονικοποίησης
    'kernel': ['rbf', 'linear', 'poly'],
    'gamma': ['scale', 'auto'] + [0.01, 0.1, 1],  # Για μη γραμμικούς πυρήνες
    'degree': [2, 3],  # Μόνο για πολυωνυμικό πυρήνα
    'class_weight': [None, 'balanced',{0: 1, 1: 2}],  # Ισορροπία κλάσεων
    'shrinking': [True],  # Ενεργοποίηση βελτιστοποίησης shrinking
}


smote = SMOTE(random_state=42)
X_res, y_res = smote.fit_resample(X_train, y_train)

grid = GridSearchCV(
    estimator=SVC(probability=True, random_state=RAND_STATE),
    param_grid=param_grid,
    scoring='roc_auc',
    cv=StratifiedKFold(n_splits=5, shuffle=True, random_state=42),
    n_jobs=-1,         # Παράλληλος υπολογισμός
    verbose=3,         # Λεπτομερής έξοδος
    refit=True
)
model = grid.fit(X_res, y_res)
best_params = grid.best_params_

print(f"✅ Best Params: {best_params}")
best_model = grid.best_estimator_
y_proba = model.predict_proba(X_val)[:, 1]
fpr, tpr, thresholds = roc_curve(y_val, y_proba)
final_auc = auc(fpr, tpr)
print("| Final AUC score on val set:", final_auc)
print('-' * 30)
# Out:
# Fitting 5 folds for each of 360 candidates, totalling 1800 fits
# [CV 2/5] END C=0.01, class_weight=None, degree=2, gamma=scale, kernel=linear, shrinking=True;, score=0.669 total time=   3.0s
# [CV 1/5] END C=0.01, class_weight=None, degree=2, gamma=scale, kernel=linear, shrinking=True;, score=0.647 total time=   3.3s
# [CV 3/5] END C=0.01, class_weight=None, degree=2, gamma=scale, kernel=linear, shrinking=True;, score=0.637 total time=   3.2s
# [CV 1/5] END C=0.01, class_weight=None, degree=2, gamma=scale, kernel=rbf, shrinking=True;, score=0.662 total time=   5.8s
# [CV 3/5] END C=0.01, class_weight=None, degree=2, gamma=scale, kernel=rbf, shrinking=True;, score=0.679 total time=   5.9s
# [CV 5/5] END C=0.01, class_weight=None, degree=2, gamma=scale, kernel=rbf, shrinking=True;, score=0.686 total time=   5.9s
# [CV 2/5] END C=0.01, class_weight=None, degree=2, gamma=scale, kernel=rbf, shrinking=True;, score=0.659 total time=   6.0s
# [CV 4/5] END C=0.01, class_weight=None, degree=2, gamma=scale, kernel=rbf, shrinking=True;, score=0.698 total time=   6.0s
# [CV 4/5] END C=0.01, class_weight=None, degree=2, gamma=scale, kernel=linear, shrinking=True;, score=0.656 total time=   3.2s
# [CV 5/5] END C=0.01, class_weight=None, degree=2, gamma=scale, kernel=linear, shrinking=True;, score=0.660 total time=   3.4s
# [CV 1/5] END C=0.01, class_weight=None, degree=2, gamma=scale, kernel=poly, shrinking=True;, score=0.595 total time=   4.1s
# [CV 2/5] END C=0.01, class_weight=None, degree=2, gamma=scale, kernel=poly, shrinking=True;, score=0.584 total time=   4.0s
# [CV 4/5] END C=0.01, class_weight=None, degree=2, gamma=scale, kernel=poly, shrinking=True;, score=0.625 total time=   4.1s
# [CV 5/5] END C=0.01, class_weight=None, degree=2, gamma=scale, kernel=poly, shrinking=True;, score=0.620 total time=   4.1s
# [CV 3/5] END C=0.01, class_weight=None, degree=2, gamma=scale, kernel=poly, shrinking=True;, score=0.644 total time=   4.4s
# [CV 1/5] END C=0.01, class_weight=None, degree=2, gamma=auto, kernel=rbf, shrinking=True;, score=0.661 total time=   6.1s
# [CV 2/5] END C=0.01, class_weight=None, degree=2, gamma=auto, kernel=rbf, shrinking=True;, score=0.658 total time=   5.8s
# [CV 3/5] END C=0.01, class_weight=None, degree=2, gamma=auto, kernel=rbf, shrinking=True;, score=0.677 total time=   6.0s
# [CV 1/5] END C=0.01, class_weight=None, degree=2, gamma=auto, kernel=linear, shrinking=True;, score=0.647 total time=   3.2s
# [CV 2/5] END C=0.01, class_weight=None, degree=2, gamma=auto, kernel=linear, shrinking=True;, score=0.669 total time=   3.3s
# [CV 4/5] END C=0.01, class_weight=None, degree=2, gamma=auto, kernel=rbf, shrinking=True;, score=0.698 total time=   6.1s
# [CV 3/5] END C=0.01, class_weight=None, degree=2, gamma=auto, kernel=linear, shrinking=True;, score=0.637 total time=   3.5s
# [CV 5/5] END C=0.01, class_weight=None, degree=2, gamma=auto, kernel=linear, shrinking=True;, score=0.660 total time=   3.3s
# [CV 4/5] END C=0.01, class_weight=None, degree=2, gamma=auto, kernel=linear, shrinking=True;, score=0.656 total time=   3.5s
# [CV 5/5] END C=0.01, class_weight=None, degree=2, gamma=auto, kernel=rbf, shrinking=True;, score=0.685 total time=   6.3s
# [CV 1/5] END C=0.01, class_weight=None, degree=2, gamma=auto, kernel=poly, shrinking=True;, score=0.595 total time=   4.4s
# [CV 3/5] END C=0.01, class_weight=None, degree=2, gamma=auto, kernel=poly, shrinking=True;, score=0.644 total time=   4.2s
# [CV 2/5] END C=0.01, class_weight=None, degree=2, gamma=auto, kernel=poly, shrinking=True;, score=0.583 total time=   4.5s
# [CV 4/5] END C=0.01, class_weight=None, degree=2, gamma=auto, kernel=poly, shrinking=True;, score=0.625 total time=   4.4s
# [CV 5/5] END C=0.01, class_weight=None, degree=2, gamma=auto, kernel=poly, shrinking=True;, score=0.620 total time=   4.3s
# [CV 1/5] END C=0.01, class_weight=None, degree=2, gamma=0.01, kernel=linear, shrinking=True;, score=0.647 total time=   3.4s
# [CV 2/5] END C=0.01, class_weight=None, degree=2, gamma=0.01, kernel=linear, shrinking=True;, score=0.669 total time=   3.4s
# [CV 3/5] END C=0.01, class_weight=None, degree=2, gamma=0.01, kernel=linear, shrinking=True;, score=0.637 total time=   3.5s
# [CV 1/5] END C=0.01, class_weight=None, degree=2, gamma=0.01, kernel=rbf, shrinking=True;, score=0.647 total time=   6.4s
# [CV 2/5] END C=0.01, class_weight=None, degree=2, gamma=0.01, kernel=rbf, shrinking=True;, score=0.647 total time=   6.6s
# [CV 3/5] END C=0.01, class_weight=None, degree=2, gamma=0.01, kernel=rbf, shrinking=True;, score=0.654 total time=   6.4s
# [CV 4/5] END C=0.01, class_weight=None, degree=2, gamma=0.01, kernel=rbf, shrinking=True;, score=0.682 total time=   6.3s
# [CV 5/5] END C=0.01, class_weight=None, degree=2, gamma=0.01, kernel=rbf, shrinking=True;, score=0.662 total time=   6.4s
# [CV 4/5] END C=0.01, class_weight=None, degree=2, gamma=0.01, kernel=linear, shrinking=True;, score=0.656 total time=   3.5s
# [CV 5/5] END C=0.01, class_weight=None, degree=2, gamma=0.01, kernel=linear, shrinking=True;, score=0.660 total time=   3.6s
# [CV 1/5] END C=0.01, class_weight=None, degree=2, gamma=0.01, kernel=poly, shrinking=True;, score=0.595 total time=   4.4s
# [CV 2/5] END C=0.01, class_weight=None, degree=2, gamma=0.01, kernel=poly, shrinking=True;, score=0.582 total time=   4.4s
# [CV 3/5] END C=0.01, class_weight=None, degree=2, gamma=0.01, kernel=poly, shrinking=True;, score=0.645 total time=   4.6s
# [CV 4/5] END C=0.01, class_weight=None, degree=2, gamma=0.01, kernel=poly, shrinking=True;, score=0.625 total time=   4.5s
# [CV 5/5] END C=0.01, class_weight=None, degree=2, gamma=0.01, kernel=poly, shrinking=True;, score=0.620 total time=   4.4s
# [CV 1/5] END C=0.01, class_weight=None, degree=2, gamma=0.1, kernel=linear, shrinking=True;, score=0.647 total time=   3.4s
# [CV 1/5] END C=0.01, class_weight=None, degree=2, gamma=0.1, kernel=rbf, shrinking=True;, score=0.680 total time=   6.4s
# [CV 2/5] END C=0.01, class_weight=None, degree=2, gamma=0.1, kernel=linear, shrinking=True;, score=0.669 total time=   3.6s
# [CV 2/5] END C=0.01, class_weight=None, degree=2, gamma=0.1, kernel=rbf, shrinking=True;, score=0.677 total time=   6.6s
# [CV 3/5] END C=0.01, class_weight=None, degree=2, gamma=0.1, kernel=rbf, shrinking=True;, score=0.703 total time=   6.5s
# [CV 3/5] END C=0.01, class_weight=None, degree=2, gamma=0.1, kernel=linear, shrinking=True;, score=0.637 total time=   3.6s
# [CV 4/5] END C=0.01, class_weight=None, degree=2, gamma=0.1, kernel=rbf, shrinking=True;, score=0.716 total time=   6.5s
# [CV 5/5] END C=0.01, class_weight=None, degree=2, gamma=0.1, kernel=rbf, shrinking=True;, score=0.704 total time=   6.7s
# [CV 4/5] END C=0.01, class_weight=None, degree=2, gamma=0.1, kernel=linear, shrinking=True;, score=0.656 total time=   3.8s
# [CV 5/5] END C=0.01, class_weight=None, degree=2, gamma=0.1, kernel=linear, shrinking=True;, score=0.660 total time=   3.9s
# [CV 1/5] END C=0.01, class_weight=None, degree=2, gamma=0.1, kernel=poly, shrinking=True;, score=0.606 total time=   4.7s
# [CV 2/5] END C=0.01, class_weight=None, degree=2, gamma=0.1, kernel=poly, shrinking=True;, score=0.598 total time=   4.7s
# [CV 3/5] END C=0.01, class_weight=None, degree=2, gamma=0.1, kernel=poly, shrinking=True;, score=0.653 total time=   4.8s
# [CV 4/5] END C=0.01, class_weight=None, degree=2, gamma=0.1, kernel=poly, shrinking=True;, score=0.647 total time=   5.0s
# [CV 5/5] END C=0.01, class_weight=None, degree=2, gamma=0.1, kernel=poly, shrinking=True;, score=0.630 total time=   4.9s
# [CV 1/5] END C=0.01, class_weight=None, degree=2, gamma=1, kernel=linear, shrinking=True;, score=0.647 total time=   3.7s
# [CV 1/5] END C=0.01, class_weight=None, degree=2, gamma=1, kernel=rbf, shrinking=True;, score=0.939 total time=   6.8s
# [CV 2/5] END C=0.01, class_weight=None, degree=2, gamma=1, kernel=linear, shrinking=True;, score=0.669 total time=   3.7s
# [CV 2/5] END C=0.01, class_weight=None, degree=2, gamma=1, kernel=rbf, shrinking=True;, score=0.939 total time=   6.8s
# [CV 3/5] END C=0.01, class_weight=None, degree=2, gamma=1, kernel=linear, shrinking=True;, score=0.637 total time=   3.7s
# [CV 3/5] END C=0.01, class_weight=None, degree=2, gamma=1, kernel=rbf, shrinking=True;, score=0.947 total time=   6.9s
# [CV 4/5] END C=0.01, class_weight=None, degree=2, gamma=1, kernel=rbf, shrinking=True;, score=0.943 total time=   6.9s
# [CV 5/5] END C=0.01, class_weight=None, degree=2, gamma=1, kernel=rbf, shrinking=True;, score=0.929 total time=   6.7s
# [CV 4/5] END C=0.01, class_weight=None, degree=2, gamma=1, kernel=linear, shrinking=True;, score=0.656 total time=   3.9s
# [CV 5/5] END C=0.01, class_weight=None, degree=2, gamma=1, kernel=linear, shrinking=True;, score=0.660 total time=   3.8s
# [CV 1/5] END C=0.01, class_weight=None, degree=2, gamma=1, kernel=poly, shrinking=True;, score=0.678 total time=   5.2s
# [CV 2/5] END C=0.01, class_weight=None, degree=2, gamma=1, kernel=poly, shrinking=True;, score=0.691 total time=   5.1s
# [CV 3/5] END C=0.01, class_weight=None, degree=2, gamma=1, kernel=poly, shrinking=True;, score=0.684 total time=   5.2s
# [CV 4/5] END C=0.01, class_weight=None, degree=2, gamma=1, kernel=poly, shrinking=True;, score=0.700 total time=   5.3s
# [CV 5/5] END C=0.01, class_weight=None, degree=2, gamma=1, kernel=poly, shrinking=True;, score=0.688 total time=   5.4s
# [CV 1/5] END C=0.01, class_weight=None, degree=3, gamma=scale, kernel=rbf, shrinking=True;, score=0.662 total time=   7.1s
# [CV 1/5] END C=0.01, class_weight=None, degree=3, gamma=scale, kernel=linear, shrinking=True;, score=0.647 total time=   3.9s
# [CV 2/5] END C=0.01, class_weight=None, degree=3, gamma=scale, kernel=linear, shrinking=True;, score=0.669 total time=   3.9s
# [CV 2/5] END C=0.01, class_weight=None, degree=3, gamma=scale, kernel=rbf, shrinking=True;, score=0.659 total time=   7.2s
# [CV 3/5] END C=0.01, class_weight=None, degree=3, gamma=scale, kernel=rbf, shrinking=True;, score=0.679 total time=   7.2s
# [CV 3/5] END C=0.01, class_weight=None, degree=3, gamma=scale, kernel=linear, shrinking=True;, score=0.637 total time=   3.9s
# [CV 4/5] END C=0.01, class_weight=None, degree=3, gamma=scale, kernel=rbf, shrinking=True;, score=0.698 total time=   7.2s
# [CV 5/5] END C=0.01, class_weight=None, degree=3, gamma=scale, kernel=rbf, shrinking=True;, score=0.686 total time=   7.1s
# [CV 4/5] END C=0.01, class_weight=None, degree=3, gamma=scale, kernel=linear, shrinking=True;, score=0.656 total time=   3.9s
# [CV 5/5] END C=0.01, class_weight=None, degree=3, gamma=scale, kernel=linear, shrinking=True;, score=0.660 total time=   4.0s
# [CV 1/5] END C=0.01, class_weight=None, degree=3, gamma=scale, kernel=poly, shrinking=True;, score=0.654 total time=   4.9s
# [CV 3/5] END C=0.01, class_weight=None, degree=3, gamma=scale, kernel=poly, shrinking=True;, score=0.664 total time=   4.9s
# [CV 2/5] END C=0.01, class_weight=None, degree=3, gamma=scale, kernel=poly, shrinking=True;, score=0.662 total time=   5.0s
# [CV 4/5] END C=0.01, class_weight=None, degree=3, gamma=scale, kernel=poly, shrinking=True;, score=0.682 total time=   5.1s
# [CV 5/5] END C=0.01, class_weight=None, degree=3, gamma=scale, kernel=poly, shrinking=True;, score=0.656 total time=   5.1s
# [CV 1/5] END C=0.01, class_weight=None, degree=3, gamma=auto, kernel=linear, shrinking=True;, score=0.647 total time=   3.9s
# [CV 1/5] END C=0.01, class_weight=None, degree=3, gamma=auto, kernel=rbf, shrinking=True;, score=0.661 total time=   7.2s
# [CV 2/5] END C=0.01, class_weight=None, degree=3, gamma=auto, kernel=linear, shrinking=True;, score=0.669 total time=   4.0s
# [CV 2/5] END C=0.01, class_weight=None, degree=3, gamma=auto, kernel=rbf, shrinking=True;, score=0.658 total time=   7.2s
# [CV 3/5] END C=0.01, class_weight=None, degree=3, gamma=auto, kernel=linear, shrinking=True;, score=0.637 total time=   4.0s
# [CV 3/5] END C=0.01, class_weight=None, degree=3, gamma=auto, kernel=rbf, shrinking=True;, score=0.677 total time=   7.5s
# [CV 4/5] END C=0.01, class_weight=None, degree=3, gamma=auto, kernel=rbf, shrinking=True;, score=0.698 total time=   7.2s
# [CV 5/5] END C=0.01, class_weight=None, degree=3, gamma=auto, kernel=rbf, shrinking=True;, score=0.685 total time=   7.0s
# [CV 4/5] END C=0.01, class_weight=None, degree=3, gamma=auto, kernel=linear, shrinking=True;, score=0.656 total time=   4.0s
# [CV 5/5] END C=0.01, class_weight=None, degree=3, gamma=auto, kernel=linear, shrinking=True;, score=0.660 total time=   4.0s
# [CV 1/5] END C=0.01, class_weight=None, degree=3, gamma=auto, kernel=poly, shrinking=True;, score=0.656 total time=   5.1s
# [CV 2/5] END C=0.01, class_weight=None, degree=3, gamma=auto, kernel=poly, shrinking=True;, score=0.658 total time=   4.9s
# [CV 4/5] END C=0.01, class_weight=None, degree=3, gamma=auto, kernel=poly, shrinking=True;, score=0.681 total time=   4.9s
# [CV 3/5] END C=0.01, class_weight=None, degree=3, gamma=auto, kernel=poly, shrinking=True;, score=0.664 total time=   5.2s
# [CV 5/5] END C=0.01, class_weight=None, degree=3, gamma=auto, kernel=poly, shrinking=True;, score=0.654 total time=   5.0s
# [CV 1/5] END C=0.01, class_weight=None, degree=3, gamma=0.01, kernel=rbf, shrinking=True;, score=0.647 total time=   7.3s
# [CV 1/5] END C=0.01, class_weight=None, degree=3, gamma=0.01, kernel=linear, shrinking=True;, score=0.647 total time=   3.8s
# [CV 2/5] END C=0.01, class_weight=None, degree=3, gamma=0.01, kernel=linear, shrinking=True;, score=0.669 total time=   4.0s
# [CV 2/5] END C=0.01, class_weight=None, degree=3, gamma=0.01, kernel=rbf, shrinking=True;, score=0.647 total time=   7.6s
# [CV 3/5] END C=0.01, class_weight=None, degree=3, gamma=0.01, kernel=linear, shrinking=True;, score=0.637 total time=   4.1s
# [CV 3/5] END C=0.01, class_weight=None, degree=3, gamma=0.01, kernel=rbf, shrinking=True;, score=0.654 total time=   7.4s
# [CV 4/5] END C=0.01, class_weight=None, degree=3, gamma=0.01, kernel=rbf, shrinking=True;, score=0.682 total time=   7.5s
# [CV 5/5] END C=0.01, class_weight=None, degree=3, gamma=0.01, kernel=rbf, shrinking=True;, score=0.662 total time=   7.3s
# [CV 4/5] END C=0.01, class_weight=None, degree=3, gamma=0.01, kernel=linear, shrinking=True;, score=0.656 total time=   4.0s
# [CV 5/5] END C=0.01, class_weight=None, degree=3, gamma=0.01, kernel=linear, shrinking=True;, score=0.660 total time=   4.0s
# [CV 1/5] END C=0.01, class_weight=None, degree=3, gamma=0.01, kernel=poly, shrinking=True;, score=0.654 total time=   5.0s
# [CV 2/5] END C=0.01, class_weight=None, degree=3, gamma=0.01, kernel=poly, shrinking=True;, score=0.641 total time=   5.1s
# [CV 4/5] END C=0.01, class_weight=None, degree=3, gamma=0.01, kernel=poly, shrinking=True;, score=0.677 total time=   5.0s
# [CV 3/5] END C=0.01, class_weight=None, degree=3, gamma=0.01, kernel=poly, shrinking=True;, score=0.659 total time=   5.1s
# [CV 5/5] END C=0.01, class_weight=None, degree=3, gamma=0.01, kernel=poly, shrinking=True;, score=0.648 total time=   5.3s
# [CV 1/5] END C=0.01, class_weight=None, degree=3, gamma=0.1, kernel=rbf, shrinking=True;, score=0.680 total time=   7.4s
# [CV 2/5] END C=0.01, class_weight=None, degree=3, gamma=0.1, kernel=linear, shrinking=True;, score=0.669 total time=   4.1s
# [CV 1/5] END C=0.01, class_weight=None, degree=3, gamma=0.1, kernel=linear, shrinking=True;, score=0.647 total time=   4.2s
# [CV 2/5] END C=0.01, class_weight=None, degree=3, gamma=0.1, kernel=rbf, shrinking=True;, score=0.677 total time=   7.6s
# [CV 3/5] END C=0.01, class_weight=None, degree=3, gamma=0.1, kernel=rbf, shrinking=True;, score=0.703 total time=   7.4s
# [CV 3/5] END C=0.01, class_weight=None, degree=3, gamma=0.1, kernel=linear, shrinking=True;, score=0.637 total time=   4.1s
# [CV 4/5] END C=0.01, class_weight=None, degree=3, gamma=0.1, kernel=rbf, shrinking=True;, score=0.716 total time=   7.5s
# [CV 5/5] END C=0.01, class_weight=None, degree=3, gamma=0.1, kernel=rbf, shrinking=True;, score=0.704 total time=   7.7s
# [CV 4/5] END C=0.01, class_weight=None, degree=3, gamma=0.1, kernel=linear, shrinking=True;, score=0.656 total time=   4.0s
# [CV 5/5] END C=0.01, class_weight=None, degree=3, gamma=0.1, kernel=linear, shrinking=True;, score=0.660 total time=   4.2s
# [CV 1/5] END C=0.01, class_weight=None, degree=3, gamma=0.1, kernel=poly, shrinking=True;, score=0.684 total time=   4.9s
# [CV 3/5] END C=0.01, class_weight=None, degree=3, gamma=0.1, kernel=poly, shrinking=True;, score=0.695 total time=   4.8s
# [CV 2/5] END C=0.01, class_weight=None, degree=3, gamma=0.1, kernel=poly, shrinking=True;, score=0.708 total time=   4.9s
# [CV 4/5] END C=0.01, class_weight=None, degree=3, gamma=0.1, kernel=poly, shrinking=True;, score=0.715 total time=   4.9s
# [CV 5/5] END C=0.01, class_weight=None, degree=3, gamma=0.1, kernel=poly, shrinking=True;, score=0.682 total time=   4.9s
# [CV 1/5] END C=0.01, class_weight=None, degree=3, gamma=1, kernel=linear, shrinking=True;, score=0.647 total time=   4.2s
# [CV 2/5] END C=0.01, class_weight=None, degree=3, gamma=1, kernel=linear, shrinking=True;, score=0.669 total time=   4.0s
# [CV 1/5] END C=0.01, class_weight=None, degree=3, gamma=1, kernel=rbf, shrinking=True;, score=0.939 total time=   7.5s
# [CV 2/5] END C=0.01, class_weight=None, degree=3, gamma=1, kernel=rbf, shrinking=True;, score=0.939 total time=   7.5s
# [CV 3/5] END C=0.01, class_weight=None, degree=3, gamma=1, kernel=rbf, shrinking=True;, score=0.947 total time=   7.5s
# [CV 3/5] END C=0.01, class_weight=None, degree=3, gamma=1, kernel=linear, shrinking=True;, score=0.637 total time=   4.2s
# [CV 4/5] END C=0.01, class_weight=None, degree=3, gamma=1, kernel=rbf, shrinking=True;, score=0.943 total time=   7.6s
# [CV 5/5] END C=0.01, class_weight=None, degree=3, gamma=1, kernel=rbf, shrinking=True;, score=0.929 total time=   7.6s
# [CV 4/5] END C=0.01, class_weight=None, degree=3, gamma=1, kernel=linear, shrinking=True;, score=0.656 total time=   4.1s
# [CV 5/5] END C=0.01, class_weight=None, degree=3, gamma=1, kernel=linear, shrinking=True;, score=0.660 total time=   4.2s
# [CV 1/5] END C=0.01, class_weight=balanced, degree=2, gamma=scale, kernel=rbf, shrinking=True;, score=0.662 total time=   7.5s
# [CV 2/5] END C=0.01, class_weight=balanced, degree=2, gamma=scale, kernel=rbf, shrinking=True;, score=0.659 total time=   8.0s
# [CV 3/5] END C=0.01, class_weight=balanced, degree=2, gamma=scale, kernel=rbf, shrinking=True;, score=0.679 total time=   8.1s
# [CV 1/5] END C=0.01, class_weight=balanced, degree=2, gamma=scale, kernel=linear, shrinking=True;, score=0.647 total time=   4.1s
# [CV 4/5] END C=0.01, class_weight=balanced, degree=2, gamma=scale, kernel=rbf, shrinking=True;, score=0.698 total time=   7.9s
# [CV 5/5] END C=0.01, class_weight=balanced, degree=2, gamma=scale, kernel=rbf, shrinking=True;, score=0.686 total time=   7.9s
# [CV 2/5] END C=0.01, class_weight=balanced, degree=2, gamma=scale, kernel=linear, shrinking=True;, score=0.668 total time=   4.5s
# [CV 3/5] END C=0.01, class_weight=balanced, degree=2, gamma=scale, kernel=linear, shrinking=True;, score=0.637 total time=   4.5s
# [CV 4/5] END C=0.01, class_weight=balanced, degree=2, gamma=scale, kernel=linear, shrinking=True;, score=0.656 total time=   4.5s
# [CV 5/5] END C=0.01, class_weight=balanced, degree=2, gamma=scale, kernel=linear, shrinking=True;, score=0.660 total time=   4.6s
# [CV 1/5] END C=0.01, class_weight=balanced, degree=2, gamma=scale, kernel=poly, shrinking=True;, score=0.595 total time=   5.3s
# [CV 2/5] END C=0.01, class_weight=balanced, degree=2, gamma=scale, kernel=poly, shrinking=True;, score=0.584 total time=   5.6s
# [CV 3/5] END C=0.01, class_weight=balanced, degree=2, gamma=scale, kernel=poly, shrinking=True;, score=0.644 total time=   5.6s
# [CV 4/5] END C=0.01, class_weight=balanced, degree=2, gamma=scale, kernel=poly, shrinking=True;, score=0.624 total time=   5.6s
# [CV 5/5] END C=0.01, class_weight=balanced, degree=2, gamma=scale, kernel=poly, shrinking=True;, score=0.621 total time=   5.7s
# [CV 1/5] END C=0.01, class_weight=balanced, degree=2, gamma=auto, kernel=rbf, shrinking=True;, score=0.661 total time=   7.8s
# [CV 2/5] END C=0.01, class_weight=balanced, degree=2, gamma=auto, kernel=rbf, shrinking=True;, score=0.658 total time=   8.2s
# [CV 3/5] END C=0.01, class_weight=balanced, degree=2, gamma=auto, kernel=rbf, shrinking=True;, score=0.677 total time=   8.1s
# [CV 4/5] END C=0.01, class_weight=balanced, degree=2, gamma=auto, kernel=rbf, shrinking=True;, score=0.698 total time=   8.1s
# [CV 1/5] END C=0.01, class_weight=balanced, degree=2, gamma=auto, kernel=linear, shrinking=True;, score=0.647 total time=   4.1s
# [CV 5/5] END C=0.01, class_weight=balanced, degree=2, gamma=auto, kernel=rbf, shrinking=True;, score=0.685 total time=   8.2s
# [CV 2/5] END C=0.01, class_weight=balanced, degree=2, gamma=auto, kernel=linear, shrinking=True;, score=0.668 total time=   4.7s
# [CV 3/5] END C=0.01, class_weight=balanced, degree=2, gamma=auto, kernel=linear, shrinking=True;, score=0.637 total time=   4.7s
# [CV 4/5] END C=0.01, class_weight=balanced, degree=2, gamma=auto, kernel=linear, shrinking=True;, score=0.656 total time=   4.6s
# [CV 1/5] END C=0.01, class_weight=None, degree=3, gamma=1, kernel=poly, shrinking=True;, score=0.692 total time=  55.9s
# [CV 5/5] END C=0.01, class_weight=balanced, degree=2, gamma=auto, kernel=linear, shrinking=True;, score=0.660 total time=   4.7s
# [CV 3/5] END C=0.01, class_weight=None, degree=3, gamma=1, kernel=poly, shrinking=True;, score=0.713 total time=  55.5s
# [CV 1/5] END C=0.01, class_weight=balanced, degree=2, gamma=auto, kernel=poly, shrinking=True;, score=0.595 total time=   5.5s
# [CV 2/5] END C=0.01, class_weight=None, degree=3, gamma=1, kernel=poly, shrinking=True;, score=0.718 total time=  57.8s
# [CV 5/5] END C=0.01, class_weight=None, degree=3, gamma=1, kernel=poly, shrinking=True;, score=0.721 total time=  57.8s
# [CV 2/5] END C=0.01, class_weight=balanced, degree=2, gamma=auto, kernel=poly, shrinking=True;, score=0.582 total time=   5.8s
# [CV 4/5] END C=0.01, class_weight=None, degree=3, gamma=1, kernel=poly, shrinking=True;, score=0.699 total time= 1.0min
# [CV 3/5] END C=0.01, class_weight=balanced, degree=2, gamma=auto, kernel=poly, shrinking=True;, score=0.644 total time=   5.7s
# [CV 5/5] END C=0.01, class_weight=balanced, degree=2, gamma=auto, kernel=poly, shrinking=True;, score=0.621 total time=   5.6s
# [CV 4/5] END C=0.01, class_weight=balanced, degree=2, gamma=auto, kernel=poly, shrinking=True;, score=0.624 total time=   5.8s
# [CV 1/5] END C=0.01, class_weight=balanced, degree=2, gamma=0.01, kernel=rbf, shrinking=True;, score=0.647 total time=   8.0s
# [CV 1/5] END C=0.01, class_weight=balanced, degree=2, gamma=0.01, kernel=linear, shrinking=True;, score=0.647 total time=   4.2s
# [CV 2/5] END C=0.01, class_weight=balanced, degree=2, gamma=0.01, kernel=rbf, shrinking=True;, score=0.647 total time=   8.3s
# [CV 3/5] END C=0.01, class_weight=balanced, degree=2, gamma=0.01, kernel=linear, shrinking=True;, score=0.637 total time=   4.6s
# [CV 2/5] END C=0.01, class_weight=balanced, degree=2, gamma=0.01, kernel=linear, shrinking=True;, score=0.668 total time=   4.9s
# [CV 3/5] END C=0.01, class_weight=balanced, degree=2, gamma=0.01, kernel=rbf, shrinking=True;, score=0.654 total time=   8.3s
# [CV 4/5] END C=0.01, class_weight=balanced, degree=2, gamma=0.01, kernel=rbf, shrinking=True;, score=0.682 total time=   8.3s
# [CV 5/5] END C=0.01, class_weight=balanced, degree=2, gamma=0.01, kernel=rbf, shrinking=True;, score=0.662 total time=   8.4s
# [CV 4/5] END C=0.01, class_weight=balanced, degree=2, gamma=0.01, kernel=linear, shrinking=True;, score=0.656 total time=   4.7s
# [CV 5/5] END C=0.01, class_weight=balanced, degree=2, gamma=0.01, kernel=linear, shrinking=True;, score=0.660 total time=   4.6s
# [CV 1/5] END C=0.01, class_weight=balanced, degree=2, gamma=0.01, kernel=poly, shrinking=True;, score=0.595 total time=   5.4s
# [CV 2/5] END C=0.01, class_weight=balanced, degree=2, gamma=0.01, kernel=poly, shrinking=True;, score=0.582 total time=   5.7s
# [CV 3/5] END C=0.01, class_weight=balanced, degree=2, gamma=0.01, kernel=poly, shrinking=True;, score=0.644 total time=   5.7s
# [CV 4/5] END C=0.01, class_weight=balanced, degree=2, gamma=0.01, kernel=poly, shrinking=True;, score=0.624 total time=   5.6s
# [CV 5/5] END C=0.01, class_weight=balanced, degree=2, gamma=0.01, kernel=poly, shrinking=True;, score=0.621 total time=   5.8s
# [CV 1/5] END C=0.01, class_weight=balanced, degree=2, gamma=0.1, kernel=linear, shrinking=True;, score=0.647 total time=   4.2s
# [CV 1/5] END C=0.01, class_weight=balanced, degree=2, gamma=0.1, kernel=rbf, shrinking=True;, score=0.680 total time=   7.7s
# [CV 2/5] END C=0.01, class_weight=balanced, degree=2, gamma=0.1, kernel=linear, shrinking=True;, score=0.668 total time=   4.6s
# [CV 2/5] END C=0.01, class_weight=balanced, degree=2, gamma=0.1, kernel=rbf, shrinking=True;, score=0.677 total time=   8.0s
# [CV 3/5] END C=0.01, class_weight=balanced, degree=2, gamma=0.1, kernel=rbf, shrinking=True;, score=0.703 total time=   8.2s
# [CV 3/5] END C=0.01, class_weight=balanced, degree=2, gamma=0.1, kernel=linear, shrinking=True;, score=0.637 total time=   4.7s
# [CV 4/5] END C=0.01, class_weight=balanced, degree=2, gamma=0.1, kernel=rbf, shrinking=True;, score=0.716 total time=   8.0s
# [CV 5/5] END C=0.01, class_weight=balanced, degree=2, gamma=0.1, kernel=rbf, shrinking=True;, score=0.704 total time=   8.1s
# [CV 4/5] END C=0.01, class_weight=balanced, degree=2, gamma=0.1, kernel=linear, shrinking=True;, score=0.656 total time=   4.8s
# [CV 5/5] END C=0.01, class_weight=balanced, degree=2, gamma=0.1, kernel=linear, shrinking=True;, score=0.660 total time=   4.5s
# [CV 1/5] END C=0.01, class_weight=balanced, degree=2, gamma=0.1, kernel=poly, shrinking=True;, score=0.606 total time=   5.3s
# [CV 2/5] END C=0.01, class_weight=balanced, degree=2, gamma=0.1, kernel=poly, shrinking=True;, score=0.598 total time=   5.6s
# [CV 3/5] END C=0.01, class_weight=balanced, degree=2, gamma=0.1, kernel=poly, shrinking=True;, score=0.653 total time=   5.5s
# [CV 4/5] END C=0.01, class_weight=balanced, degree=2, gamma=0.1, kernel=poly, shrinking=True;, score=0.647 total time=   5.6s
# [CV 5/5] END C=0.01, class_weight=balanced, degree=2, gamma=0.1, kernel=poly, shrinking=True;, score=0.630 total time=   5.7s
# [CV 1/5] END C=0.01, class_weight=balanced, degree=2, gamma=1, kernel=linear, shrinking=True;, score=0.647 total time=   4.1s
# [CV 1/5] END C=0.01, class_weight=balanced, degree=2, gamma=1, kernel=rbf, shrinking=True;, score=0.939 total time=   8.0s
# [CV 2/5] END C=0.01, class_weight=balanced, degree=2, gamma=1, kernel=linear, shrinking=True;, score=0.668 total time=   4.6s
# [CV 2/5] END C=0.01, class_weight=balanced, degree=2, gamma=1, kernel=rbf, shrinking=True;, score=0.939 total time=   7.9s
# [CV 3/5] END C=0.01, class_weight=balanced, degree=2, gamma=1, kernel=rbf, shrinking=True;, score=0.947 total time=   7.9s
# [CV 3/5] END C=0.01, class_weight=balanced, degree=2, gamma=1, kernel=linear, shrinking=True;, score=0.637 total time=   4.6s
# [CV 4/5] END C=0.01, class_weight=balanced, degree=2, gamma=1, kernel=rbf, shrinking=True;, score=0.943 total time=   8.0s
# [CV 5/5] END C=0.01, class_weight=balanced, degree=2, gamma=1, kernel=rbf, shrinking=True;, score=0.929 total time=   8.1s
# [CV 5/5] END C=0.01, class_weight=balanced, degree=2, gamma=1, kernel=linear, shrinking=True;, score=0.660 total time=   4.7s
# [CV 4/5] END C=0.01, class_weight=balanced, degree=2, gamma=1, kernel=linear, shrinking=True;, score=0.656 total time=   4.8s
# [CV 1/5] END C=0.01, class_weight=balanced, degree=2, gamma=1, kernel=poly, shrinking=True;, score=0.678 total time=   5.9s
# [CV 2/5] END C=0.01, class_weight=balanced, degree=2, gamma=1, kernel=poly, shrinking=True;, score=0.691 total time=   5.8s
# [CV 3/5] END C=0.01, class_weight=balanced, degree=2, gamma=1, kernel=poly, shrinking=True;, score=0.684 total time=   5.9s
# [CV 4/5] END C=0.01, class_weight=balanced, degree=2, gamma=1, kernel=poly, shrinking=True;, score=0.700 total time=   6.0s
# [CV 5/5] END C=0.01, class_weight=balanced, degree=2, gamma=1, kernel=poly, shrinking=True;, score=0.688 total time=   5.9s
# [CV 1/5] END C=0.01, class_weight=balanced, degree=3, gamma=scale, kernel=linear, shrinking=True;, score=0.647 total time=   4.2s
# [CV 1/5] END C=0.01, class_weight=balanced, degree=3, gamma=scale, kernel=rbf, shrinking=True;, score=0.662 total time=   8.0s
# [CV 2/5] END C=0.01, class_weight=balanced, degree=3, gamma=scale, kernel=linear, shrinking=True;, score=0.668 total time=   4.6s
# [CV 3/5] END C=0.01, class_weight=balanced, degree=3, gamma=scale, kernel=rbf, shrinking=True;, score=0.679 total time=   7.9s
# [CV 2/5] END C=0.01, class_weight=balanced, degree=3, gamma=scale, kernel=rbf, shrinking=True;, score=0.659 total time=   8.2s
# [CV 3/5] END C=0.01, class_weight=balanced, degree=3, gamma=scale, kernel=linear, shrinking=True;, score=0.637 total time=   4.7s
# [CV 4/5] END C=0.01, class_weight=balanced, degree=3, gamma=scale, kernel=rbf, shrinking=True;, score=0.698 total time=   8.3s
# [CV 5/5] END C=0.01, class_weight=balanced, degree=3, gamma=scale, kernel=rbf, shrinking=True;, score=0.686 total time=   8.3s
# [CV 4/5] END C=0.01, class_weight=balanced, degree=3, gamma=scale, kernel=linear, shrinking=True;, score=0.656 total time=   4.7s
# [CV 5/5] END C=0.01, class_weight=balanced, degree=3, gamma=scale, kernel=linear, shrinking=True;, score=0.660 total time=   4.7s
# [CV 1/5] END C=0.01, class_weight=balanced, degree=3, gamma=scale, kernel=poly, shrinking=True;, score=0.654 total time=   5.3s
# [CV 2/5] END C=0.01, class_weight=balanced, degree=3, gamma=scale, kernel=poly, shrinking=True;, score=0.662 total time=   5.7s
# [CV 3/5] END C=0.01, class_weight=balanced, degree=3, gamma=scale, kernel=poly, shrinking=True;, score=0.664 total time=   5.8s
# [CV 4/5] END C=0.01, class_weight=balanced, degree=3, gamma=scale, kernel=poly, shrinking=True;, score=0.682 total time=   5.8s
# [CV 5/5] END C=0.01, class_weight=balanced, degree=3, gamma=scale, kernel=poly, shrinking=True;, score=0.656 total time=   5.6s
# [CV 1/5] END C=0.01, class_weight=balanced, degree=3, gamma=auto, kernel=rbf, shrinking=True;, score=0.661 total time=   7.8s
# [CV 1/5] END C=0.01, class_weight=balanced, degree=3, gamma=auto, kernel=linear, shrinking=True;, score=0.647 total time=   4.3s
# [CV 2/5] END C=0.01, class_weight=balanced, degree=3, gamma=auto, kernel=linear, shrinking=True;, score=0.668 total time=   4.7s
# [CV 2/5] END C=0.01, class_weight=balanced, degree=3, gamma=auto, kernel=rbf, shrinking=True;, score=0.658 total time=   8.2s
# [CV 3/5] END C=0.01, class_weight=balanced, degree=3, gamma=auto, kernel=rbf, shrinking=True;, score=0.677 total time=   8.4s
# [CV 3/5] END C=0.01, class_weight=balanced, degree=3, gamma=auto, kernel=linear, shrinking=True;, score=0.637 total time=   4.7s
# [CV 4/5] END C=0.01, class_weight=balanced, degree=3, gamma=auto, kernel=rbf, shrinking=True;, score=0.698 total time=   8.1s
# [CV 5/5] END C=0.01, class_weight=balanced, degree=3, gamma=auto, kernel=rbf, shrinking=True;, score=0.685 total time=   8.1s
# [CV 4/5] END C=0.01, class_weight=balanced, degree=3, gamma=auto, kernel=linear, shrinking=True;, score=0.656 total time=   4.5s
# [CV 5/5] END C=0.01, class_weight=balanced, degree=3, gamma=auto, kernel=linear, shrinking=True;, score=0.660 total time=   4.6s
# [CV 1/5] END C=0.01, class_weight=balanced, degree=3, gamma=auto, kernel=poly, shrinking=True;, score=0.656 total time=   5.3s
# [CV 2/5] END C=0.01, class_weight=balanced, degree=3, gamma=auto, kernel=poly, shrinking=True;, score=0.658 total time=   5.8s
# [CV 3/5] END C=0.01, class_weight=balanced, degree=3, gamma=auto, kernel=poly, shrinking=True;, score=0.663 total time=   5.8s
# [CV 4/5] END C=0.01, class_weight=balanced, degree=3, gamma=auto, kernel=poly, shrinking=True;, score=0.682 total time=   5.7s
# [CV 5/5] END C=0.01, class_weight=balanced, degree=3, gamma=auto, kernel=poly, shrinking=True;, score=0.654 total time=   5.8s
# [CV 1/5] END C=0.01, class_weight=balanced, degree=3, gamma=0.01, kernel=rbf, shrinking=True;, score=0.647 total time=   8.0s
# [CV 1/5] END C=0.01, class_weight=balanced, degree=3, gamma=0.01, kernel=linear, shrinking=True;, score=0.647 total time=   4.3s
# [CV 2/5] END C=0.01, class_weight=balanced, degree=3, gamma=0.01, kernel=rbf, shrinking=True;, score=0.647 total time=   8.2s
# [CV 2/5] END C=0.01, class_weight=balanced, degree=3, gamma=0.01, kernel=linear, shrinking=True;, score=0.668 total time=   4.8s
# [CV 3/5] END C=0.01, class_weight=balanced, degree=3, gamma=0.01, kernel=rbf, shrinking=True;, score=0.654 total time=   8.3s
# [CV 3/5] END C=0.01, class_weight=balanced, degree=3, gamma=0.01, kernel=linear, shrinking=True;, score=0.637 total time=   4.5s
# [CV 4/5] END C=0.01, class_weight=balanced, degree=3, gamma=0.01, kernel=rbf, shrinking=True;, score=0.682 total time=   8.3s
# [CV 5/5] END C=0.01, class_weight=balanced, degree=3, gamma=0.01, kernel=rbf, shrinking=True;, score=0.662 total time=   8.3s
# [CV 5/5] END C=0.01, class_weight=balanced, degree=3, gamma=0.01, kernel=linear, shrinking=True;, score=0.660 total time=   4.5s
# [CV 4/5] END C=0.01, class_weight=balanced, degree=3, gamma=0.01, kernel=linear, shrinking=True;, score=0.656 total time=   4.8s
# [CV 1/5] END C=0.01, class_weight=balanced, degree=3, gamma=0.01, kernel=poly, shrinking=True;, score=0.654 total time=   5.4s
# [CV 2/5] END C=0.01, class_weight=balanced, degree=3, gamma=0.01, kernel=poly, shrinking=True;, score=0.641 total time=   5.7s
# [CV 3/5] END C=0.01, class_weight=balanced, degree=3, gamma=0.01, kernel=poly, shrinking=True;, score=0.659 total time=   5.7s
# [CV 4/5] END C=0.01, class_weight=balanced, degree=3, gamma=0.01, kernel=poly, shrinking=True;, score=0.677 total time=   5.8s
# [CV 5/5] END C=0.01, class_weight=balanced, degree=3, gamma=0.01, kernel=poly, shrinking=True;, score=0.646 total time=   5.8s
# [CV 1/5] END C=0.01, class_weight=balanced, degree=3, gamma=0.1, kernel=linear, shrinking=True;, score=0.647 total time=   4.4s
# [CV 1/5] END C=0.01, class_weight=balanced, degree=3, gamma=0.1, kernel=rbf, shrinking=True;, score=0.680 total time=   8.0s
# [CV 2/5] END C=0.01, class_weight=balanced, degree=3, gamma=0.1, kernel=linear, shrinking=True;, score=0.668 total time=   4.7s
# [CV 2/5] END C=0.01, class_weight=balanced, degree=3, gamma=0.1, kernel=rbf, shrinking=True;, score=0.677 total time=   8.1s
# [CV 3/5] END C=0.01, class_weight=balanced, degree=3, gamma=0.1, kernel=rbf, shrinking=True;, score=0.703 total time=   8.3s
# [CV 3/5] END C=0.01, class_weight=balanced, degree=3, gamma=0.1, kernel=linear, shrinking=True;, score=0.637 total time=   4.8s
# [CV 4/5] END C=0.01, class_weight=balanced, degree=3, gamma=0.1, kernel=rbf, shrinking=True;, score=0.716 total time=   8.2s
# [CV 5/5] END C=0.01, class_weight=balanced, degree=3, gamma=0.1, kernel=rbf, shrinking=True;, score=0.704 total time=   8.2s
# [CV 4/5] END C=0.01, class_weight=balanced, degree=3, gamma=0.1, kernel=linear, shrinking=True;, score=0.656 total time=   4.8s
# [CV 5/5] END C=0.01, class_weight=balanced, degree=3, gamma=0.1, kernel=linear, shrinking=True;, score=0.660 total time=   4.6s
# [CV 1/5] END C=0.01, class_weight=balanced, degree=3, gamma=0.1, kernel=poly, shrinking=True;, score=0.684 total time=   5.1s
# [CV 2/5] END C=0.01, class_weight=balanced, degree=3, gamma=0.1, kernel=poly, shrinking=True;, score=0.708 total time=   5.6s
# [CV 3/5] END C=0.01, class_weight=balanced, degree=3, gamma=0.1, kernel=poly, shrinking=True;, score=0.695 total time=   5.5s
# [CV 4/5] END C=0.01, class_weight=balanced, degree=3, gamma=0.1, kernel=poly, shrinking=True;, score=0.715 total time=   5.4s
# [CV 5/5] END C=0.01, class_weight=balanced, degree=3, gamma=0.1, kernel=poly, shrinking=True;, score=0.682 total time=   5.5s
# [CV 1/5] END C=0.01, class_weight=balanced, degree=3, gamma=1, kernel=linear, shrinking=True;, score=0.647 total time=   4.2s
# [CV 1/5] END C=0.01, class_weight=balanced, degree=3, gamma=1, kernel=rbf, shrinking=True;, score=0.939 total time=   7.8s
# [CV 2/5] END C=0.01, class_weight=balanced, degree=3, gamma=1, kernel=linear, shrinking=True;, score=0.668 total time=   4.6s
# [CV 2/5] END C=0.01, class_weight=balanced, degree=3, gamma=1, kernel=rbf, shrinking=True;, score=0.939 total time=   8.1s
# [CV 3/5] END C=0.01, class_weight=balanced, degree=3, gamma=1, kernel=rbf, shrinking=True;, score=0.947 total time=   7.9s
# [CV 3/5] END C=0.01, class_weight=balanced, degree=3, gamma=1, kernel=linear, shrinking=True;, score=0.637 total time=   4.7s
# [CV 4/5] END C=0.01, class_weight=balanced, degree=3, gamma=1, kernel=rbf, shrinking=True;, score=0.943 total time=   8.1s
# [CV 5/5] END C=0.01, class_weight=balanced, degree=3, gamma=1, kernel=rbf, shrinking=True;, score=0.929 total time=   8.1s
# [CV 4/5] END C=0.01, class_weight=balanced, degree=3, gamma=1, kernel=linear, shrinking=True;, score=0.656 total time=   4.7s
# [CV 5/5] END C=0.01, class_weight=balanced, degree=3, gamma=1, kernel=linear, shrinking=True;, score=0.660 total time=   4.7s
# [CV 1/5] END C=0.01, class_weight={0: 1, 1: 2}, degree=2, gamma=scale, kernel=rbf, shrinking=True;, score=0.724 total time=   6.4s
# [CV 2/5] END C=0.01, class_weight={0: 1, 1: 2}, degree=2, gamma=scale, kernel=rbf, shrinking=True;, score=0.725 total time=   6.3s
# [CV 3/5] END C=0.01, class_weight={0: 1, 1: 2}, degree=2, gamma=scale, kernel=rbf, shrinking=True;, score=0.731 total time=   6.2s
# [CV 1/5] END C=0.01, class_weight={0: 1, 1: 2}, degree=2, gamma=scale, kernel=linear, shrinking=True;, score=0.634 total time=   3.8s
# [CV 4/5] END C=0.01, class_weight={0: 1, 1: 2}, degree=2, gamma=scale, kernel=rbf, shrinking=True;, score=0.751 total time=   6.4s
# [CV 5/5] END C=0.01, class_weight={0: 1, 1: 2}, degree=2, gamma=scale, kernel=rbf, shrinking=True;, score=0.737 total time=   6.5s
# [CV 2/5] END C=0.01, class_weight={0: 1, 1: 2}, degree=2, gamma=scale, kernel=linear, shrinking=True;, score=0.616 total time=   3.9s
# [CV 3/5] END C=0.01, class_weight={0: 1, 1: 2}, degree=2, gamma=scale, kernel=linear, shrinking=True;, score=0.618 total time=   3.9s
# [CV 4/5] END C=0.01, class_weight={0: 1, 1: 2}, degree=2, gamma=scale, kernel=linear, shrinking=True;, score=0.640 total time=   3.9s
# [CV 5/5] END C=0.01, class_weight={0: 1, 1: 2}, degree=2, gamma=scale, kernel=linear, shrinking=True;, score=0.649 total time=   3.9s
# [CV 1/5] END C=0.01, class_weight={0: 1, 1: 2}, degree=2, gamma=scale, kernel=poly, shrinking=True;, score=0.680 total time=   4.9s
# [CV 2/5] END C=0.01, class_weight={0: 1, 1: 2}, degree=2, gamma=scale, kernel=poly, shrinking=True;, score=0.684 total time=   4.9s
# [CV 3/5] END C=0.01, class_weight={0: 1, 1: 2}, degree=2, gamma=scale, kernel=poly, shrinking=True;, score=0.682 total time=   5.1s
# [CV 4/5] END C=0.01, class_weight={0: 1, 1: 2}, degree=2, gamma=scale, kernel=poly, shrinking=True;, score=0.702 total time=   5.0s
# [CV 5/5] END C=0.01, class_weight={0: 1, 1: 2}, degree=2, gamma=scale, kernel=poly, shrinking=True;, score=0.675 total time=   5.0s
# [CV 1/5] END C=0.01, class_weight={0: 1, 1: 2}, degree=2, gamma=auto, kernel=rbf, shrinking=True;, score=0.723 total time=   6.5s
# [CV 2/5] END C=0.01, class_weight={0: 1, 1: 2}, degree=2, gamma=auto, kernel=rbf, shrinking=True;, score=0.725 total time=   6.4s
# [CV 3/5] END C=0.01, class_weight={0: 1, 1: 2}, degree=2, gamma=auto, kernel=rbf, shrinking=True;, score=0.730 total time=   6.5s
# [CV 4/5] END C=0.01, class_weight={0: 1, 1: 2}, degree=2, gamma=auto, kernel=rbf, shrinking=True;, score=0.749 total time=   6.4s
# [CV 1/5] END C=0.01, class_weight={0: 1, 1: 2}, degree=2, gamma=auto, kernel=linear, shrinking=True;, score=0.634 total time=   3.9s
# [CV 5/5] END C=0.01, class_weight={0: 1, 1: 2}, degree=2, gamma=auto, kernel=rbf, shrinking=True;, score=0.737 total time=   6.5s
# [CV 2/5] END C=0.01, class_weight={0: 1, 1: 2}, degree=2, gamma=auto, kernel=linear, shrinking=True;, score=0.616 total time=   4.0s
# [CV 3/5] END C=0.01, class_weight={0: 1, 1: 2}, degree=2, gamma=auto, kernel=linear, shrinking=True;, score=0.618 total time=   3.9s
# [CV 4/5] END C=0.01, class_weight={0: 1, 1: 2}, degree=2, gamma=auto, kernel=linear, shrinking=True;, score=0.640 total time=   4.2s
# [CV 5/5] END C=0.01, class_weight={0: 1, 1: 2}, degree=2, gamma=auto, kernel=linear, shrinking=True;, score=0.649 total time=   4.1s
# [CV 1/5] END C=0.01, class_weight={0: 1, 1: 2}, degree=2, gamma=auto, kernel=poly, shrinking=True;, score=0.680 total time=   5.1s
# [CV 2/5] END C=0.01, class_weight={0: 1, 1: 2}, degree=2, gamma=auto, kernel=poly, shrinking=True;, score=0.693 total time=   4.9s
# [CV 3/5] END C=0.01, class_weight={0: 1, 1: 2}, degree=2, gamma=auto, kernel=poly, shrinking=True;, score=0.684 total time=   4.9s
# [CV 4/5] END C=0.01, class_weight={0: 1, 1: 2}, degree=2, gamma=auto, kernel=poly, shrinking=True;, score=0.698 total time=   5.0s
# [CV 5/5] END C=0.01, class_weight={0: 1, 1: 2}, degree=2, gamma=auto, kernel=poly, shrinking=True;, score=0.673 total time=   5.0s
# [CV 1/5] END C=0.01, class_weight=balanced, degree=3, gamma=1, kernel=poly, shrinking=True;, score=0.692 total time=  57.6s
# [CV 2/5] END C=0.01, class_weight=balanced, degree=3, gamma=1, kernel=poly, shrinking=True;, score=0.718 total time=  57.5s
# [CV 3/5] END C=0.01, class_weight=balanced, degree=3, gamma=1, kernel=poly, shrinking=True;, score=0.713 total time=  57.5s
# [CV 1/5] END C=0.01, class_weight={0: 1, 1: 2}, degree=2, gamma=0.01, kernel=rbf, shrinking=True;, score=0.708 total time=   6.5s
# [CV 2/5] END C=0.01, class_weight={0: 1, 1: 2}, degree=2, gamma=0.01, kernel=rbf, shrinking=True;, score=0.709 total time=   6.5s
# [CV 5/5] END C=0.01, class_weight=balanced, degree=3, gamma=1, kernel=poly, shrinking=True;, score=0.721 total time= 1.0min
# [CV 4/5] END C=0.01, class_weight=balanced, degree=3, gamma=1, kernel=poly, shrinking=True;, score=0.699 total time= 1.0min
# [CV 1/5] END C=0.01, class_weight={0: 1, 1: 2}, degree=2, gamma=0.01, kernel=linear, shrinking=True;, score=0.634 total time=   4.0s
# [CV 3/5] END C=0.01, class_weight={0: 1, 1: 2}, degree=2, gamma=0.01, kernel=rbf, shrinking=True;, score=0.710 total time=   6.3s
# [CV 2/5] END C=0.01, class_weight={0: 1, 1: 2}, degree=2, gamma=0.01, kernel=linear, shrinking=True;, score=0.616 total time=   3.9s
# [CV 4/5] END C=0.01, class_weight={0: 1, 1: 2}, degree=2, gamma=0.01, kernel=rbf, shrinking=True;, score=0.717 total time=   6.4s
# [CV 5/5] END C=0.01, class_weight={0: 1, 1: 2}, degree=2, gamma=0.01, kernel=rbf, shrinking=True;, score=0.716 total time=   6.5s
# [CV 3/5] END C=0.01, class_weight={0: 1, 1: 2}, degree=2, gamma=0.01, kernel=linear, shrinking=True;, score=0.618 total time=   3.9s
# [CV 4/5] END C=0.01, class_weight={0: 1, 1: 2}, degree=2, gamma=0.01, kernel=linear, shrinking=True;, score=0.640 total time=   4.0s
# [CV 5/5] END C=0.01, class_weight={0: 1, 1: 2}, degree=2, gamma=0.01, kernel=linear, shrinking=True;, score=0.649 total time=   3.9s
# [CV 1/5] END C=0.01, class_weight={0: 1, 1: 2}, degree=2, gamma=0.01, kernel=poly, shrinking=True;, score=0.614 total time=   4.5s
# [CV 2/5] END C=0.01, class_weight={0: 1, 1: 2}, degree=2, gamma=0.01, kernel=poly, shrinking=True;, score=0.619 total time=   4.5s
# [CV 3/5] END C=0.01, class_weight={0: 1, 1: 2}, degree=2, gamma=0.01, kernel=poly, shrinking=True;, score=0.601 total time=   4.5s
# [CV 4/5] END C=0.01, class_weight={0: 1, 1: 2}, degree=2, gamma=0.01, kernel=poly, shrinking=True;, score=0.635 total time=   4.5s
# [CV 5/5] END C=0.01, class_weight={0: 1, 1: 2}, degree=2, gamma=0.01, kernel=poly, shrinking=True;, score=0.611 total time=   4.4s
# [CV 1/5] END C=0.01, class_weight={0: 1, 1: 2}, degree=2, gamma=0.1, kernel=linear, shrinking=True;, score=0.634 total time=   3.9s
# [CV 1/5] END C=0.01, class_weight={0: 1, 1: 2}, degree=2, gamma=0.1, kernel=rbf, shrinking=True;, score=0.755 total time=   6.8s
# [CV 2/5] END C=0.01, class_weight={0: 1, 1: 2}, degree=2, gamma=0.1, kernel=linear, shrinking=True;, score=0.616 total time=   3.9s
# [CV 2/5] END C=0.01, class_weight={0: 1, 1: 2}, degree=2, gamma=0.1, kernel=rbf, shrinking=True;, score=0.755 total time=   6.7s
# [CV 3/5] END C=0.01, class_weight={0: 1, 1: 2}, degree=2, gamma=0.1, kernel=linear, shrinking=True;, score=0.618 total time=   3.9s
# [CV 3/5] END C=0.01, class_weight={0: 1, 1: 2}, degree=2, gamma=0.1, kernel=rbf, shrinking=True;, score=0.760 total time=   6.8s
# [CV 4/5] END C=0.01, class_weight={0: 1, 1: 2}, degree=2, gamma=0.1, kernel=rbf, shrinking=True;, score=0.785 total time=   6.9s
# [CV 5/5] END C=0.01, class_weight={0: 1, 1: 2}, degree=2, gamma=0.1, kernel=rbf, shrinking=True;, score=0.764 total time=   6.8s
# [CV 4/5] END C=0.01, class_weight={0: 1, 1: 2}, degree=2, gamma=0.1, kernel=linear, shrinking=True;, score=0.640 total time=   3.9s
# [CV 5/5] END C=0.01, class_weight={0: 1, 1: 2}, degree=2, gamma=0.1, kernel=linear, shrinking=True;, score=0.649 total time=   3.9s
# [CV 1/5] END C=0.01, class_weight={0: 1, 1: 2}, degree=2, gamma=0.1, kernel=poly, shrinking=True;, score=0.681 total time=   5.0s
# [CV 3/5] END C=0.01, class_weight={0: 1, 1: 2}, degree=2, gamma=0.1, kernel=poly, shrinking=True;, score=0.684 total time=   5.0s
# [CV 2/5] END C=0.01, class_weight={0: 1, 1: 2}, degree=2, gamma=0.1, kernel=poly, shrinking=True;, score=0.691 total time=   5.3s
# [CV 4/5] END C=0.01, class_weight={0: 1, 1: 2}, degree=2, gamma=0.1, kernel=poly, shrinking=True;, score=0.705 total time=   5.2s
# [CV 5/5] END C=0.01, class_weight={0: 1, 1: 2}, degree=2, gamma=0.1, kernel=poly, shrinking=True;, score=0.676 total time=   5.0s
# [CV 2/5] END C=0.01, class_weight={0: 1, 1: 2}, degree=2, gamma=1, kernel=linear, shrinking=True;, score=0.616 total time=   3.8s
# [CV 1/5] END C=0.01, class_weight={0: 1, 1: 2}, degree=2, gamma=1, kernel=linear, shrinking=True;, score=0.634 total time=   3.9s
# [CV 1/5] END C=0.01, class_weight={0: 1, 1: 2}, degree=2, gamma=1, kernel=rbf, shrinking=True;, score=0.939 total time=   8.1s
# [CV 3/5] END C=0.01, class_weight={0: 1, 1: 2}, degree=2, gamma=1, kernel=linear, shrinking=True;, score=0.618 total time=   3.9s
# [CV 2/5] END C=0.01, class_weight={0: 1, 1: 2}, degree=2, gamma=1, kernel=rbf, shrinking=True;, score=0.939 total time=   8.2s
# [CV 3/5] END C=0.01, class_weight={0: 1, 1: 2}, degree=2, gamma=1, kernel=rbf, shrinking=True;, score=0.947 total time=   8.1s
# [CV 4/5] END C=0.01, class_weight={0: 1, 1: 2}, degree=2, gamma=1, kernel=rbf, shrinking=True;, score=0.943 total time=   8.2s
# [CV 5/5] END C=0.01, class_weight={0: 1, 1: 2}, degree=2, gamma=1, kernel=linear, shrinking=True;, score=0.649 total time=   3.8s
# [CV 4/5] END C=0.01, class_weight={0: 1, 1: 2}, degree=2, gamma=1, kernel=linear, shrinking=True;, score=0.640 total time=   3.9s
# [CV 5/5] END C=0.01, class_weight={0: 1, 1: 2}, degree=2, gamma=1, kernel=rbf, shrinking=True;, score=0.929 total time=   8.0s
# [CV 1/5] END C=0.01, class_weight={0: 1, 1: 2}, degree=2, gamma=1, kernel=poly, shrinking=True;, score=0.682 total time=   6.5s
# [CV 2/5] END C=0.01, class_weight={0: 1, 1: 2}, degree=2, gamma=1, kernel=poly, shrinking=True;, score=0.694 total time=   6.4s
# [CV 3/5] END C=0.01, class_weight={0: 1, 1: 2}, degree=2, gamma=1, kernel=poly, shrinking=True;, score=0.688 total time=   6.5s
# [CV 4/5] END C=0.01, class_weight={0: 1, 1: 2}, degree=2, gamma=1, kernel=poly, shrinking=True;, score=0.710 total time=   6.7s
# [CV 5/5] END C=0.01, class_weight={0: 1, 1: 2}, degree=2, gamma=1, kernel=poly, shrinking=True;, score=0.683 total time=   6.5s
# [CV 1/5] END C=0.01, class_weight={0: 1, 1: 2}, degree=3, gamma=scale, kernel=rbf, shrinking=True;, score=0.724 total time=   6.7s
# [CV 3/5] END C=0.01, class_weight={0: 1, 1: 2}, degree=3, gamma=scale, kernel=rbf, shrinking=True;, score=0.731 total time=   6.7s
# [CV 2/5] END C=0.01, class_weight={0: 1, 1: 2}, degree=3, gamma=scale, kernel=rbf, shrinking=True;, score=0.725 total time=   6.8s
# [CV 1/5] END C=0.01, class_weight={0: 1, 1: 2}, degree=3, gamma=scale, kernel=linear, shrinking=True;, score=0.634 total time=   4.0s
# [CV 2/5] END C=0.01, class_weight={0: 1, 1: 2}, degree=3, gamma=scale, kernel=linear, shrinking=True;, score=0.616 total time=   4.0s
# ...
# [CV 5/5] END C=1, class_weight=balanced, degree=2, gamma=0.1, kernel=poly, shrinking=True;, score=0.688 total time=   6.4s
# [CV 2/5] END C=1, class_weight=balanced, degree=2, gamma=1, kernel=rbf, shrinking=True;, score=0.942 total time=   9.4s
# [CV 1/5] END C=1, class_weight=balanced, degree=2, gamma=1, kernel=rbf, shrinking=True;, score=0.941 total time=   9.6s
# [CV 3/5] END C=1, class_weight=balanced, degree=2, gamma=1, kernel=rbf, shrinking=True;, score=0.946 total time=   9.3s
# [CV 4/5] END C=1, class_weight=balanced, degree=2, gamma=1, kernel=rbf, shrinking=True;, score=0.945 total time=   9.6s
# [CV 5/5] END C=1, class_weight=balanced, degree=2, gamma=1, kernel=rbf, shrinking=True;, score=0.932 total time=   9.6s
# [CV 1/5] END C=1, class_weight=balanced, degree=2, gamma=1, kernel=linear, shrinking=True;, score=0.643 total time=   8.0s
# [CV 2/5] END C=1, class_weight=balanced, degree=2, gamma=1, kernel=linear, shrinking=True;, score=0.669 total time=   8.0s
# [CV 3/5] END C=1, class_weight=balanced, degree=2, gamma=1, kernel=linear, shrinking=True;, score=0.635 total time=   7.8s
# [CV 4/5] END C=1, class_weight=balanced, degree=2, gamma=1, kernel=linear, shrinking=True;, score=0.650 total time=   8.1s
# [CV 5/5] END C=1, class_weight=balanced, degree=2, gamma=1, kernel=linear, shrinking=True;, score=0.661 total time=   8.1s
# [CV 1/5] END C=1, class_weight=balanced, degree=2, gamma=1, kernel=poly, shrinking=True;, score=0.690 total time= 2.1min
# [CV 3/5] END C=1, class_weight=balanced, degree=2, gamma=1, kernel=poly, shrinking=True;, score=0.694 total time= 2.0min
# [CV 2/5] END C=1, class_weight=balanced, degree=2, gamma=1, kernel=poly, shrinking=True;, score=0.701 total time= 2.2min
# [CV 1/5] END C=1, class_weight=balanced, degree=3, gamma=scale, kernel=rbf, shrinking=True;, score=0.787 total time=   7.2s
# [CV 2/5] END C=1, class_weight=balanced, degree=3, gamma=scale, kernel=rbf, shrinking=True;, score=0.781 total time=   7.4s
# [CV 3/5] END C=1, class_weight=balanced, degree=3, gamma=scale, kernel=rbf, shrinking=True;, score=0.788 total time=   7.6s
# [CV 4/5] END C=1, class_weight=balanced, degree=3, gamma=scale, kernel=rbf, shrinking=True;, score=0.799 total time=   7.5s
# [CV 5/5] END C=1, class_weight=balanced, degree=3, gamma=scale, kernel=rbf, shrinking=True;, score=0.784 total time=   7.5s
# [CV 1/5] END C=1, class_weight=balanced, degree=3, gamma=scale, kernel=linear, shrinking=True;, score=0.643 total time=   8.0s
# [CV 2/5] END C=1, class_weight=balanced, degree=3, gamma=scale, kernel=linear, shrinking=True;, score=0.669 total time=   7.8s
# [CV 3/5] END C=1, class_weight=balanced, degree=3, gamma=scale, kernel=linear, shrinking=True;, score=0.635 total time=   7.7s
# [CV 4/5] END C=1, class_weight=balanced, degree=3, gamma=scale, kernel=linear, shrinking=True;, score=0.650 total time=   8.2s
# [CV 5/5] END C=1, class_weight=balanced, degree=3, gamma=scale, kernel=linear, shrinking=True;, score=0.661 total time=   8.0s
# [CV 1/5] END C=1, class_weight=balanced, degree=3, gamma=scale, kernel=poly, shrinking=True;, score=0.718 total time=   5.7s
# [CV 2/5] END C=1, class_weight=balanced, degree=3, gamma=scale, kernel=poly, shrinking=True;, score=0.734 total time=   6.0s
# [CV 3/5] END C=1, class_weight=balanced, degree=3, gamma=scale, kernel=poly, shrinking=True;, score=0.732 total time=   5.8s
# [CV 4/5] END C=1, class_weight=balanced, degree=3, gamma=scale, kernel=poly, shrinking=True;, score=0.733 total time=   6.1s
# [CV 5/5] END C=1, class_weight=balanced, degree=3, gamma=scale, kernel=poly, shrinking=True;, score=0.717 total time=   6.0s
# [CV 1/5] END C=1, class_weight=balanced, degree=3, gamma=auto, kernel=rbf, shrinking=True;, score=0.781 total time=   7.1s
# [CV 2/5] END C=1, class_weight=balanced, degree=3, gamma=auto, kernel=rbf, shrinking=True;, score=0.777 total time=   7.8s
# [CV 4/5] END C=1, class_weight=balanced, degree=2, gamma=1, kernel=poly, shrinking=True;, score=0.713 total time= 2.2min
# [CV 5/5] END C=1, class_weight=balanced, degree=2, gamma=1, kernel=poly, shrinking=True;, score=0.699 total time= 2.2min
# [CV 3/5] END C=1, class_weight=balanced, degree=3, gamma=auto, kernel=rbf, shrinking=True;, score=0.783 total time=   7.4s
# [CV 4/5] END C=1, class_weight=balanced, degree=3, gamma=auto, kernel=rbf, shrinking=True;, score=0.795 total time=   7.6s
# [CV 5/5] END C=1, class_weight=balanced, degree=3, gamma=auto, kernel=rbf, shrinking=True;, score=0.780 total time=   7.7s
# [CV 1/5] END C=1, class_weight=balanced, degree=3, gamma=auto, kernel=linear, shrinking=True;, score=0.643 total time=   8.2s
# [CV 2/5] END C=1, class_weight=balanced, degree=3, gamma=auto, kernel=linear, shrinking=True;, score=0.669 total time=   8.3s
# [CV 3/5] END C=1, class_weight=balanced, degree=3, gamma=auto, kernel=linear, shrinking=True;, score=0.635 total time=   8.0s
# [CV 1/5] END C=1, class_weight=balanced, degree=3, gamma=auto, kernel=poly, shrinking=True;, score=0.717 total time=   6.0s
# [CV 4/5] END C=1, class_weight=balanced, degree=3, gamma=auto, kernel=linear, shrinking=True;, score=0.650 total time=   8.5s
# [CV 5/5] END C=1, class_weight=balanced, degree=3, gamma=auto, kernel=linear, shrinking=True;, score=0.661 total time=   8.3s
# [CV 2/5] END C=1, class_weight=balanced, degree=3, gamma=auto, kernel=poly, shrinking=True;, score=0.735 total time=   6.1s
# [CV 3/5] END C=1, class_weight=balanced, degree=3, gamma=auto, kernel=poly, shrinking=True;, score=0.731 total time=   6.0s
# [CV 4/5] END C=1, class_weight=balanced, degree=3, gamma=auto, kernel=poly, shrinking=True;, score=0.733 total time=   6.0s
# [CV 5/5] END C=1, class_weight=balanced, degree=3, gamma=auto, kernel=poly, shrinking=True;, score=0.715 total time=   6.0s
# [CV 1/5] END C=1, class_weight=balanced, degree=3, gamma=0.01, kernel=rbf, shrinking=True;, score=0.705 total time=   7.8s
# [CV 2/5] END C=1, class_weight=balanced, degree=3, gamma=0.01, kernel=rbf, shrinking=True;, score=0.710 total time=   8.0s
# [CV 3/5] END C=1, class_weight=balanced, degree=3, gamma=0.01, kernel=rbf, shrinking=True;, score=0.703 total time=   8.0s
# [CV 4/5] END C=1, class_weight=balanced, degree=3, gamma=0.01, kernel=rbf, shrinking=True;, score=0.721 total time=   8.0s
# [CV 5/5] END C=1, class_weight=balanced, degree=3, gamma=0.01, kernel=rbf, shrinking=True;, score=0.715 total time=   8.1s
# [CV 1/5] END C=1, class_weight=balanced, degree=3, gamma=0.01, kernel=linear, shrinking=True;, score=0.643 total time=   8.0s
# [CV 2/5] END C=1, class_weight=balanced, degree=3, gamma=0.01, kernel=linear, shrinking=True;, score=0.669 total time=   8.2s
# [CV 3/5] END C=1, class_weight=balanced, degree=3, gamma=0.01, kernel=linear, shrinking=True;, score=0.635 total time=   8.0s
# [CV 4/5] END C=1, class_weight=balanced, degree=3, gamma=0.01, kernel=linear, shrinking=True;, score=0.650 total time=   8.7s
# [CV 1/5] END C=1, class_weight=balanced, degree=3, gamma=0.01, kernel=poly, shrinking=True;, score=0.656 total time=   6.4s
# [CV 5/5] END C=1, class_weight=balanced, degree=3, gamma=0.01, kernel=linear, shrinking=True;, score=0.661 total time=   9.1s
# [CV 2/5] END C=1, class_weight=balanced, degree=3, gamma=0.01, kernel=poly, shrinking=True;, score=0.659 total time=   6.8s
# [CV 3/5] END C=1, class_weight=balanced, degree=3, gamma=0.01, kernel=poly, shrinking=True;, score=0.664 total time=   6.5s
# [CV 4/5] END C=1, class_weight=balanced, degree=3, gamma=0.01, kernel=poly, shrinking=True;, score=0.682 total time=   6.5s
# [CV 5/5] END C=1, class_weight=balanced, degree=3, gamma=0.01, kernel=poly, shrinking=True;, score=0.654 total time=   6.6s
# [CV 1/5] END C=1, class_weight=balanced, degree=3, gamma=0.1, kernel=rbf, shrinking=True;, score=0.862 total time=   7.7s
# [CV 2/5] END C=1, class_weight=balanced, degree=3, gamma=0.1, kernel=rbf, shrinking=True;, score=0.850 total time=   7.8s
# [CV 3/5] END C=1, class_weight=balanced, degree=3, gamma=0.1, kernel=rbf, shrinking=True;, score=0.855 total time=   7.9s
# [CV 4/5] END C=1, class_weight=balanced, degree=3, gamma=0.1, kernel=rbf, shrinking=True;, score=0.866 total time=   7.8s
# [CV 5/5] END C=1, class_weight=balanced, degree=3, gamma=0.1, kernel=rbf, shrinking=True;, score=0.847 total time=   7.9s
# [CV 1/5] END C=1, class_weight=balanced, degree=3, gamma=0.1, kernel=linear, shrinking=True;, score=0.643 total time=   8.1s
# [CV 2/5] END C=1, class_weight=balanced, degree=3, gamma=0.1, kernel=linear, shrinking=True;, score=0.669 total time=   8.4s
# [CV 3/5] END C=1, class_weight=balanced, degree=3, gamma=0.1, kernel=linear, shrinking=True;, score=0.635 total time=   8.2s
# [CV 4/5] END C=1, class_weight=balanced, degree=3, gamma=0.1, kernel=linear, shrinking=True;, score=0.650 total time=   8.6s
# [CV 5/5] END C=1, class_weight=balanced, degree=3, gamma=0.1, kernel=linear, shrinking=True;, score=0.661 total time=   8.7s
# [CV 1/5] END C=1, class_weight=balanced, degree=3, gamma=0.1, kernel=poly, shrinking=True;, score=0.710 total time=  10.1s
# [CV 2/5] END C=1, class_weight=balanced, degree=3, gamma=0.1, kernel=poly, shrinking=True;, score=0.724 total time=  10.7s
# [CV 3/5] END C=1, class_weight=balanced, degree=3, gamma=0.1, kernel=poly, shrinking=True;, score=0.734 total time=  10.7s
# [CV 4/5] END C=1, class_weight=balanced, degree=3, gamma=0.1, kernel=poly, shrinking=True;, score=0.719 total time=  10.7s
# [CV 5/5] END C=1, class_weight=balanced, degree=3, gamma=0.1, kernel=poly, shrinking=True;, score=0.715 total time=  10.8s
# [CV 1/5] END C=1, class_weight=balanced, degree=3, gamma=1, kernel=rbf, shrinking=True;, score=0.941 total time=  10.0s
# [CV 2/5] END C=1, class_weight=balanced, degree=3, gamma=1, kernel=rbf, shrinking=True;, score=0.942 total time=   9.9s
# [CV 3/5] END C=1, class_weight=balanced, degree=3, gamma=1, kernel=rbf, shrinking=True;, score=0.946 total time=   9.9s
# [CV 4/5] END C=1, class_weight=balanced, degree=3, gamma=1, kernel=rbf, shrinking=True;, score=0.945 total time=  10.0s
# [CV 5/5] END C=1, class_weight=balanced, degree=3, gamma=1, kernel=rbf, shrinking=True;, score=0.932 total time=  10.0s
# [CV 1/5] END C=1, class_weight=balanced, degree=3, gamma=1, kernel=linear, shrinking=True;, score=0.643 total time=   8.1s
# [CV 2/5] END C=1, class_weight=balanced, degree=3, gamma=1, kernel=linear, shrinking=True;, score=0.669 total time=   8.2s
# [CV 3/5] END C=1, class_weight=balanced, degree=3, gamma=1, kernel=linear, shrinking=True;, score=0.635 total time=   8.2s
# [CV 4/5] END C=1, class_weight=balanced, degree=3, gamma=1, kernel=linear, shrinking=True;, score=0.650 total time=   8.5s
# [CV 5/5] END C=1, class_weight=balanced, degree=3, gamma=1, kernel=linear, shrinking=True;, score=0.661 total time=   8.4s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 43
#      32 X_res, y_res = smote.fit_resample(X_train, y_train)
#      34 grid = GridSearchCV(
#      35     estimator=SVC(probability=True, random_state=RAND_STATE),
#      36     param_grid=param_grid,
#    (...)
#      41     refit=True
#      42 )
# ---> 43 model = grid.fit(X_res, y_res)
#      44 best_params = grid.best_params_
#      46 print(f"✅ Best Params: {best_params}")
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_search.py:1019, in BaseSearchCV.fit(self, X, y, **params)
#    1013     results = self._format_results(
#    1014         all_candidate_params, n_splits, all_out, all_more_results
#    1015     )
#    1017     return results
# -> 1019 self._run_search(evaluate_candidates)
#    1021 # multimetric is determined here because in the case of a callable
#    1022 # self.scoring the return type is only known after calling
#    1023 first_test_score = all_out[0]["test_scores"]
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_search.py:1573, in GridSearchCV._run_search(self, evaluate_candidates)
#    1571 def _run_search(self, evaluate_candidates):
#    1572     """Search all candidates in param_grid"""
# -> 1573     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_search.py:965, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     957 if self.verbose > 0:
#     958     print(
#     959         "Fitting {0} folds for each of {1} candidates,"
#     960         " totalling {2} fits".format(
#     961             n_splits, n_candidates, n_candidates * n_splits
#     962         )
#     963     )
# --> 965 out = parallel(
#     966     delayed(_fit_and_score)(
#     967         clone(base_estimator),
#     968         X,
#     969         y,
#     970         train=train,
#     971         test=test,
#     972         parameters=parameters,
#     973         split_progress=(split_idx, n_splits),
#     974         candidate_progress=(cand_idx, n_candidates),
#     975         **fit_and_score_kwargs,
#     976     )
#     977     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     978         enumerate(candidate_params),
#     979         enumerate(cv.split(X, y, **routed_params.splitter.split)),
#     980     )
#     981 )
#     983 if len(out) < 1:
#     984     raise ValueError(
#     985         "No fits were performed. "
#     986         "Was the CV iterator empty? "
#     987         "Were there no candidates?"
#     988     )
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/utils/parallel.py:74, in Parallel.__call__(self, iterable)
#      69 config = get_config()
#      70 iterable_with_config = (
#      71     (_with_config(delayed_func, config), args, kwargs)
#      72     for delayed_func, args, kwargs in iterable
#      73 )
# ---> 74 return super().__call__(iterable_with_config)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/joblib/parallel.py:2007, in Parallel.__call__(self, iterable)
#    2001 # The first item from the output is blank, but it makes the interpreter
#    2002 # progress until it enters the Try/Except block of the generator and
#    2003 # reaches the first `yield` statement. This starts the asynchronous
#    2004 # dispatch of the tasks to the workers.
#    2005 next(output)
# -> 2007 return output if self.return_generator else list(output)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/joblib/parallel.py:1650, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1647     yield
#    1649     with self._backend.retrieval_context():
# -> 1650         yield from self._retrieve()
#    1652 except GeneratorExit:
#    1653     # The generator has been garbage collected before being fully
#    1654     # consumed. This aborts the remaining tasks if possible and warn
#    1655     # the user if necessary.
#    1656     self._exception = True
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/joblib/parallel.py:1762, in Parallel._retrieve(self)
#    1757 # If the next job is not ready for retrieval yet, we just wait for
#    1758 # async callbacks to progress.
#    1759 if ((len(self._jobs) == 0) or
#    1760     (self._jobs[0].get_status(
#    1761         timeout=self.timeout) == TASK_PENDING)):
# -> 1762     time.sleep(0.01)
#    1763     continue
#    1765 # We need to be careful: the job list can be filling up as
#    1766 # we empty it and Python list are not thread-safe by
#    1767 # default hence the use of the lock
#
# KeyboardInterrupt:

# %%
best_model=SVC(
    C = 0.1,
    kernel = 'rbf',
    gamma = 0.1,
    class_weight = None,
    shrinking = True,
    probability = True,
    random_state = RAND_STATE
)

# %%
best_model.fit(X_res, y_res)
# Out:
# SVC(C=0.1, gamma=1, probability=True, random_state=42)

# %%
test_probs = best_model.predict_proba(test_set)[:, 1]

# %%
# Construct IdFeedback column
ids = []
for i in range(len(test_subjects)):
    name = f'S{test_subjects[i]}'
    for session in range(1, 5):
        for fid in range(1, 61):
            ids.append(f'{name}_Sess{session:02}_FB{fid:03}')
    for fid in range(1, 101):
        ids.append(f'{name}_Sess05_FB{fid:03}')
ids = np.array(ids)
print(f'ids: {ids.shape}')
print(ids)
# Out:
# ids: (3400,)
# ['S01_Sess01_FB001' 'S01_Sess01_FB002' 'S01_Sess01_FB003' ...
#  'S25_Sess05_FB098' 'S25_Sess05_FB099' 'S25_Sess05_FB100']

# %%
# Αποθήκευση των αποτελεσμάτων
svm_result = pd.DataFrame({
    'IdFeedback': ids,
    'Prediction': test_probs,
})
svm_result.to_csv('submissions/svm4.csv', sep=',', index=False)
